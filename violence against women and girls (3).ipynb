# %%
#for manipulation
import pandas as pd
import numpy as np
#for visualization
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact
import plotly.express    as px

# %% [markdown]
# # Data Loading,Storage.

# %%
#Lets read the dataset
data=pd.read_csv('dataset.zip')
data.count()
# Out:
# RecordID                 12600
# Country                  12600
# Gender                   12600
# Demographics Question    12600
# Demographics Response    12600
# Question                 12600
# Survey Year              12600
# Value                    11187
# dtype: int64

# %%
data.head(5)
# Out:
#    RecordID      Country Gender Demographics Question  \
# 0         1  Afghanistan      F        Marital status
# 1         1  Afghanistan      F             Education
# 2         1  Afghanistan      F             Education
# 3         1  Afghanistan      F             Education
# 4         1  Afghanistan      F        Marital status
#
#           Demographics Response                   Question Survey Year  Value
# 0                 Never married  ... if she burns the food  01/01/2015    NaN
# 1                        Higher  ... if she burns the food  01/01/2015   10.1
# 2                     Secondary  ... if she burns the food  01/01/2015   13.7
# 3                       Primary  ... if she burns the food  01/01/2015   13.8
# 4  Widowed, divorced, separated  ... if she burns the food  01/01/2015   13.8

# %%
data.tail(5)
# Out:
#        RecordID   Country Gender Demographics Question Demographics Response  \
# 12595       210  Zimbabwe      M             Residence                 Urban
# 12596       280  Zimbabwe      M             Residence                 Rural
# 12597       280  Zimbabwe      M             Residence                 Urban
# 12598       350  Zimbabwe      M             Residence                 Rural
# 12599       350  Zimbabwe      M             Residence                 Urban
#
#                                       Question Survey Year  Value
# 12595  ... if she goes out without telling him  01/01/2015   11.8
# 12596         ... if she neglects the children  01/01/2015   20.1
# 12597         ... if she neglects the children  01/01/2015   15.0
# 12598  ... if she refuses to have sex with him  01/01/2015    7.2
# 12599  ... if she refuses to have sex with him  01/01/2015    3.7

# %%
#Lets check the shape of the dataset
print("shape of the dataset:",data.shape)
# Out:
# shape of the dataset: (12600, 8)

# %%
#lets check the dimension of dataframe
print("dimension of dataset:",data.ndim)
# Out:
# dimension of dataset: 2

# %%
print("size of dataset:",data.size)
# Out:
# size of dataset: 100800

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
#column type
type(data['Country'])
# Out:
# pandas.core.series.Series

# %%
#if we acces the single column by there name
data['Gender']
# Out:
# 0        F
# 1        F
# 2        F
# 3        F
# 4        F
#         ..
# 12595    M
# 12596    M
# 12597    M
# 12598    M
# 12599    M
# Name: Gender, Length: 12600, dtype: object

# %%
data.iloc[0:3]
# Out:
#    RecordID      Country Gender Demographics Question Demographics Response  \
# 0         1  Afghanistan      F        Marital status         Never married
# 1         1  Afghanistan      F             Education                Higher
# 2         1  Afghanistan      F             Education             Secondary
#
#                     Question Survey Year  Value
# 0  ... if she burns the food  01/01/2015    NaN
# 1  ... if she burns the food  01/01/2015   10.1
# 2  ... if she burns the food  01/01/2015   13.7

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=12600, step=1),
#  Index(['RecordID', 'Country', 'Gender', 'Demographics Question',
#         'Demographics Response', 'Question', 'Survey Year', 'Value'],
#        dtype='object')]

# %%
#attribute style (it have some restriction)
data.Country
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 12595       Zimbabwe
# 12596       Zimbabwe
# 12597       Zimbabwe
# 12598       Zimbabwe
# 12599       Zimbabwe
# Name: Country, Length: 12600, dtype: object

# %%
data.values   #dataframe as 2D array
# Out:
# array([[1, 'Afghanistan', 'F', ..., '... if she burns the food',
#         '01/01/2015', nan],
#        [1, 'Afghanistan', 'F', ..., '... if she burns the food',
#         '01/01/2015', 10.1],
#        [1, 'Afghanistan', 'F', ..., '... if she burns the food',
#         '01/01/2015', 13.7],
#        ...,
#        [280, 'Zimbabwe', 'M', ..., '... if she neglects the children',
#         '01/01/2015', 15.0],
#        [350, 'Zimbabwe', 'M', ...,
#         '... if she refuses to have sex with him', '01/01/2015', 7.2],
#        [350, 'Zimbabwe', 'M', ...,
#         '... if she refuses to have sex with him', '01/01/2015', 3.7]],
#       dtype=object)

# %%
data.Country.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Angola', 'Armenia', 'Azerbaijan',
#        'Bangladesh', 'Benin', 'Bolivia', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Chad', 'Colombia', 'Comoros', 'Congo',
#        'Congo Democratic Republic', "Cote d'Ivoire", 'Dominican Republic',
#        'Egypt', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia',
#        'Ghana', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'India', 'Indonesia', 'Jordan', 'Kenya', 'Kyrgyz Republic',
#        'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Maldives', 'Mali',
#        'Moldova', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal',
#        'Nicaragua', 'Niger', 'Nigeria', 'Pakistan', 'Peru', 'Philippines',
#        'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Sierra Leone',
#        'South Africa', 'Tajikistan', 'Tanzania', 'Timor-Leste', 'Togo',
#        'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
data['Country'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Angola', 'Armenia', 'Azerbaijan',
#        'Bangladesh', 'Benin', 'Bolivia', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Chad', 'Colombia', 'Comoros', 'Congo',
#        'Congo Democratic Republic', "Cote d'Ivoire", 'Dominican Republic',
#        'Egypt', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia',
#        'Ghana', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'India', 'Indonesia', 'Jordan', 'Kenya', 'Kyrgyz Republic',
#        'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Maldives', 'Mali',
#        'Moldova', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal',
#        'Nicaragua', 'Niger', 'Nigeria', 'Pakistan', 'Peru', 'Philippines',
#        'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Sierra Leone',
#        'South Africa', 'Tajikistan', 'Tanzania', 'Timor-Leste', 'Togo',
#        'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
data.Question.unique()
# Out:
# array(['... if she burns the food',
#        '... for at least one specific reason',
#        '... if she argues with him',
#        '... if she goes out without telling him',
#        '... if she neglects the children',
#        '... if she refuses to have sex with him'], dtype=object)

# %%
data['Demographics Question'].unique().tolist()
# Out:
# ['Marital status', 'Education', 'Employment', 'Age', 'Residence']

# %%
data[data.Gender=='F']
# Out:
#        RecordID      Country Gender Demographics Question  \
# 0             1  Afghanistan      F        Marital status
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 4             1  Afghanistan      F        Marital status
# ...         ...          ...    ...                   ...
# 12505       210     Zimbabwe      F             Residence
# 12506       280     Zimbabwe      F             Residence
# 12507       280     Zimbabwe      F             Residence
# 12508       350     Zimbabwe      F             Residence
# 12509       350     Zimbabwe      F             Residence
#
#               Demographics Response                                 Question  \
# 0                     Never married                ... if she burns the food
# 1                            Higher                ... if she burns the food
# 2                         Secondary                ... if she burns the food
# 3                           Primary                ... if she burns the food
# 4      Widowed, divorced, separated                ... if she burns the food
# ...                             ...                                      ...
# 12505                         Urban  ... if she goes out without telling him
# 12506                         Rural         ... if she neglects the children
# 12507                         Urban         ... if she neglects the children
# 12508                         Rural  ... if she refuses to have sex with him
# 12509                         Urban  ... if she refuses to have sex with him
#
#       Survey Year  Value
# 0      01/01/2015    NaN
# 1      01/01/2015   10.1
# 2      01/01/2015   13.7
# 3      01/01/2015   13.8
# 4      01/01/2015   13.8
# ...           ...    ...
# 12505  01/01/2015   14.2
# 12506  01/01/2015   24.3
# 12507  01/01/2015   16.7
# 12508  01/01/2015   18.2
# 12509  01/01/2015    8.6
#
# [6300 rows x 8 columns]

# %%
data[data.Gender=='M']
# Out:
#        RecordID      Country Gender Demographics Question  \
# 15            1  Afghanistan      M        Marital status
# 16            1  Afghanistan      M             Education
# 17            1  Afghanistan      M             Residence
# 18            1  Afghanistan      M            Employment
# 19            1  Afghanistan      M             Education
# ...         ...          ...    ...                   ...
# 12595       210     Zimbabwe      M             Residence
# 12596       280     Zimbabwe      M             Residence
# 12597       280     Zimbabwe      M             Residence
# 12598       350     Zimbabwe      M             Residence
# 12599       350     Zimbabwe      M             Residence
#
#       Demographics Response                                 Question  \
# 15            Never married                ... if she burns the food
# 16                   Higher                ... if she burns the food
# 17                    Urban                ... if she burns the food
# 18               Unemployed                ... if she burns the food
# 19                  Primary                ... if she burns the food
# ...                     ...                                      ...
# 12595                 Urban  ... if she goes out without telling him
# 12596                 Rural         ... if she neglects the children
# 12597                 Urban         ... if she neglects the children
# 12598                 Rural  ... if she refuses to have sex with him
# 12599                 Urban  ... if she refuses to have sex with him
#
#       Survey Year  Value
# 15     01/01/2015    NaN
# 16     01/01/2015    4.5
# 17     01/01/2015    4.6
# 18     01/01/2015    5.2
# 19     01/01/2015    6.3
# ...           ...    ...
# 12595  01/01/2015   11.8
# 12596  01/01/2015   20.1
# 12597  01/01/2015   15.0
# 12598  01/01/2015    7.2
# 12599  01/01/2015    3.7
#
# [6300 rows x 8 columns]

# %% [markdown]
#  # Data Cleaning

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12600 entries, 0 to 12599
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   RecordID               12600 non-null  int64
#  1   Country                12600 non-null  object
#  2   Gender                 12600 non-null  object
#  3   Demographics Question  12600 non-null  object
#  4   Demographics Response  12600 non-null  object
#  5   Question               12600 non-null  object
#  6   Survey Year            12600 non-null  object
#  7   Value                  11187 non-null  float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 787.6+ KB

# %%
#Check Duplicates
data.duplicated().sum()
# Out:
# 0

# %%
# lets check if there is any missing value in the dataset
data.isna()
# Out:
#        RecordID  Country  Gender  Demographics Question  \
# 0         False    False   False                  False
# 1         False    False   False                  False
# 2         False    False   False                  False
# 3         False    False   False                  False
# 4         False    False   False                  False
# ...         ...      ...     ...                    ...
# 12595     False    False   False                  False
# 12596     False    False   False                  False
# 12597     False    False   False                  False
# 12598     False    False   False                  False
# 12599     False    False   False                  False
#
#        Demographics Response  Question  Survey Year  Value
# 0                      False     False        False   True
# 1                      False     False        False  False
# 2                      False     False        False  False
# 3                      False     False        False  False
# 4                      False     False        False  False
# ...                      ...       ...          ...    ...
# 12595                  False     False        False  False
# 12596                  False     False        False  False
# 12597                  False     False        False  False
# 12598                  False     False        False  False
# 12599                  False     False        False  False
#
# [12600 rows x 8 columns]

# %%
data.isnull().sum()
# Out:
# RecordID                    0
# Country                     0
# Gender                      0
# Demographics Question       0
# Demographics Response       0
# Question                    0
# Survey Year                 0
# Value                    1413
# dtype: int64

# %%
dn = pd.DataFrame({
    'Unique':data.nunique(),
    'Null':data.isna().sum(),
    'NullPercent':data.isna().sum() / len(data),
    'Type':data.dtypes.values
})
print(dn)
# Out:
#                        Unique  Null  NullPercent     Type
# RecordID                  420     0     0.000000    int64
# Country                    70     0     0.000000   object
# Gender                      2     0     0.000000   object
# Demographics Question       5     0     0.000000   object
# Demographics Response      15     0     0.000000   object
# Question                    6     0     0.000000   object
# Survey Year                18     0     0.000000   object
# Value                     757  1413     0.112143  float64

# %%
#DROP ROWs
dn=data.dropna()
dn
# Out:
#        RecordID      Country Gender Demographics Question  \
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 4             1  Afghanistan      F        Marital status
# 5             1  Afghanistan      F            Employment
# ...         ...          ...    ...                   ...
# 12595       210     Zimbabwe      M             Residence
# 12596       280     Zimbabwe      M             Residence
# 12597       280     Zimbabwe      M             Residence
# 12598       350     Zimbabwe      M             Residence
# 12599       350     Zimbabwe      M             Residence
#
#               Demographics Response                                 Question  \
# 1                            Higher                ... if she burns the food
# 2                         Secondary                ... if she burns the food
# 3                           Primary                ... if she burns the food
# 4      Widowed, divorced, separated                ... if she burns the food
# 5                 Employed for kind                ... if she burns the food
# ...                             ...                                      ...
# 12595                         Urban  ... if she goes out without telling him
# 12596                         Rural         ... if she neglects the children
# 12597                         Urban         ... if she neglects the children
# 12598                         Rural  ... if she refuses to have sex with him
# 12599                         Urban  ... if she refuses to have sex with him
#
#       Survey Year  Value
# 1      01/01/2015   10.1
# 2      01/01/2015   13.7
# 3      01/01/2015   13.8
# 4      01/01/2015   13.8
# 5      01/01/2015   17.0
# ...           ...    ...
# 12595  01/01/2015   11.8
# 12596  01/01/2015   20.1
# 12597  01/01/2015   15.0
# 12598  01/01/2015    7.2
# 12599  01/01/2015    3.7
#
# [11187 rows x 8 columns]

# %%
dn.isna()
# Out:
#        RecordID  Country  Gender  Demographics Question  \
# 1         False    False   False                  False
# 2         False    False   False                  False
# 3         False    False   False                  False
# 4         False    False   False                  False
# 5         False    False   False                  False
# ...         ...      ...     ...                    ...
# 12595     False    False   False                  False
# 12596     False    False   False                  False
# 12597     False    False   False                  False
# 12598     False    False   False                  False
# 12599     False    False   False                  False
#
#        Demographics Response  Question  Survey Year  Value
# 1                      False     False        False  False
# 2                      False     False        False  False
# 3                      False     False        False  False
# 4                      False     False        False  False
# 5                      False     False        False  False
# ...                      ...       ...          ...    ...
# 12595                  False     False        False  False
# 12596                  False     False        False  False
# 12597                  False     False        False  False
# 12598                  False     False        False  False
# 12599                  False     False        False  False
#
# [11187 rows x 8 columns]

# %%
dn.isnull().sum()
# Out:
# RecordID                 0
# Country                  0
# Gender                   0
# Demographics Question    0
# Demographics Response    0
# Question                 0
# Survey Year              0
# Value                    0
# dtype: int64

# %% [markdown]
# #   Mean,Median.

# %%
demographics_dn = dn.groupby(["Demographics Question", "Demographics Response"])["Value"].agg(["median", "max", "min", "mean"]).reset_index()
demographics_dn.columns = ["Question", "Response", "Median", "Max", "Min", "Mean"]
print("Violence % median, min, max, and mean per demographic group")
demographics_dn.sort_values(["Question", "Median"])
# Out:
# Violence % median, min, max, and mean per demographic group
#           Question                      Response  Median   Max  Min       Mean
# 2              Age                         35-49   14.15  81.0  0.2  19.336412
# 1              Age                         25-34   14.45  81.5  0.1  19.703562
# 0              Age                         15-24   17.50  80.1  0.1  21.084169
# 3        Education                        Higher    4.20  74.6  0.0   8.898670
# 6        Education                     Secondary   13.05  76.7  0.2  17.378892
# 5        Education                       Primary   18.40  80.5  0.1  22.819093
# 4        Education                  No education   21.55  82.0  0.0  25.403125
# 9       Employment                    Unemployed   14.55  80.1  0.0  19.539710
# 7       Employment             Employed for cash   14.85  81.5  0.1  19.553804
# 8       Employment             Employed for kind   20.15  86.9  0.3  24.445541
# 10  Marital status    Married or living together   14.80  82.1  0.2  20.181003
# 11  Marital status                 Never married   14.90  72.1  0.0  18.704360
# 12  Marital status  Widowed, divorced, separated   17.15  75.9  0.0  20.683511
# 14       Residence                         Urban   11.05  74.4  0.1  15.895778
# 13       Residence                         Rural   19.00  82.1  0.2  23.294063

# %% [markdown]
# # Data Visualization

# %%
sns.catplot(
    data=dn, y="Country", x="Value",
    kind="bar", height=12,aspect=.6,errorbar=None,
)

# %%
g = sns.catplot(x='Demographics Response',y='Value',col='Gender',hue='Question',
                order=['No education','Primary','Secondary','Higher'],
                data=dn,kind='bar',errorbar=None)
g.set_axis_labels('Education Level','Percentage (%)')
g.fig.suptitle('India agreeing a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'India agreeing a husband is justified in hitting his wife')

# %%
g = sns.catplot(x='Gender',y='Value',
                data=dn,kind='bar',errorbar=None)
g.set_axis_labels('Gender','Percentage (%)')
g.fig.suptitle(' a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, ' a husband is justified in hitting his wife')

# %%
g = sns.catplot(x='Question',y='Value',data=dn,kind='bar',errorbar=None, height=4,
    aspect=1,)
g.set_axis_labels('Questions Asked','Percentage (%)',)
g.fig.suptitle('A husband is justified in hitting his wife',y=1.05)
plt.xticks(rotation=90);

# %%
g = sns.catplot(x='Demographics Response',y='Value',
                order=['No education','Primary','Secondary','Higher'],
                data=dn,kind='bar',errorbar=None)
g.set_axis_labels('Education Level','Percentage (%)')
g.fig.suptitle('A husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'A husband is justified in hitting his wife')

# %%
g = sns.catplot(x='Demographics Response',y='Value',
                order=['No education','Higher'],
                data=dn,kind='bar',errorbar=None)
g.set_axis_labels('Education Level','Percentage (%)')
g.fig.suptitle('A husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'A husband is justified in hitting his wife')

# %%
g = sns.catplot(x='Demographics Response',y='Value',
                order=['Employed for cash','Unemployed','Employed for kind'],aspect=.9,
                data=dn,kind='bar',errorbar=None)
g.set_axis_labels('Employment','Percentage (%)')
g.fig.suptitle('Indian agreeing a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'Indian agreeing a husband is justified in hitting his wife')

# %% [markdown]
# # INDIA

# %%
India = dn[dn.Country == 'India']
India.head()
# Out:
#       RecordID Country Gender Demographics Question Demographics Response  \
# 5580        32   India      F             Education                Higher
# 5581        32   India      F             Residence                 Urban
# 5582        32   India      F        Marital status         Never married
# 5583        32   India      F             Education             Secondary
# 5584        32   India      F                   Age                 15-24
#
#                        Question Survey Year  Value
# 5580  ... if she burns the food  01/01/2015   11.4
# 5581  ... if she burns the food  01/01/2015   15.2
# 5582  ... if she burns the food  01/01/2015   15.8
# 5583  ... if she burns the food  01/01/2015   17.3
# 5584  ... if she burns the food  01/01/2015   17.5

# %%
graph = India[(India['Demographics Question'] == 'Age')]

g = sns.catplot(x='Demographics Response',y='Value',col="Gender",aspect=.6,
                data=graph,kind='bar',errorbar=None)
g.set_axis_labels('Age','Percentage (%)')
g.fig.suptitle('Indian  agreeing a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'Indian  agreeing a husband is justified in hitting his wife')

# %%
graph = India[(India['Demographics Question'] == 'Employment')]

g = sns.catplot(x='Demographics Response',y='Value',col="Gender",
                order=['Employed for cash','Employed for kind','Unemployed'],aspect=.9,
                data=graph,kind='bar',errorbar=None)
g.set_axis_labels('Employment','Percentage (%)')
g.fig.suptitle('Indian agreeing a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'Indian agreeing a husband is justified in hitting his wife')

# %%
graph = India[India['Demographics Question'] == 'Age']

g = sns.catplot(x='Demographics Response',y='Value',col='Gender',hue='Question',
                order=['15-24','25-34','35-49'],
                data=graph,kind='bar',errorbar=None)
g.set_axis_labels('Age','Percentage (%)')
g.fig.suptitle('India agreeing a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'India agreeing a husband is justified in hitting his wife')

# %%
graph = India[India['Demographics Question'] == 'Education']

g = sns.catplot(x='Demographics Response',y='Value',col='Gender',hue='Question',
                order=['No education','Primary','Secondary','Higher'],
                data=graph,kind='bar',errorbar=None)
g.set_axis_labels('Education Level','Percentage (%)')
g.fig.suptitle('India agreeing a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'India agreeing a husband is justified in hitting his wife')

# %%
graph = India[(India['Demographics Question'] == 'Education')]

g = sns.catplot(x='Demographics Response',y='Value',col="Gender",
                order=['Higher','No education',],aspect=.9,
                data=graph,kind='bar',errorbar=None)
g.set_axis_labels('Education','Percentage (%)')
g.fig.suptitle('Indian agreeing a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'Indian agreeing a husband is justified in hitting his wife')

# %%
graph = India[(India['Demographics Question'] == 'Employment')]

g = sns.catplot(x='Demographics Response',y='Value',col="Gender",
                order=['Employed for cash','Unemployed'],aspect=.9,
                data=graph,kind='bar',errorbar=None)
g.set_axis_labels('Employment','Percentage (%)')
g.fig.suptitle('Indian agreeing a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'Indian agreeing a husband is justified in hitting his wife')

# %%
graph = India[(India['Demographics Question'] == 'Residence')]

g = sns.catplot(x='Demographics Response',y='Value',col="Gender",
                order=['Rural','Urban'],aspect=.9,
                data=graph,kind='bar',errorbar=None)
g.set_axis_labels('Residence','Percentage (%)')
g.fig.suptitle('Indian agreeing a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'Indian agreeing a husband is justified in hitting his wife')

# %%
graph = India[(India['Demographics Question'] == 'Marital status')]

g = sns.catplot(x='Demographics Response',y='Value',col="Gender",
                order=['Never married','Married or living together'],aspect=.9,
                data=graph,kind='bar',errorbar=None)
g.set_axis_labels('Marital status','Percentage (%)')
g.fig.suptitle('Indian agreeing a husband is justified in hitting his wife',y=1.05)
# Out:
# Text(0.5, 1.05, 'Indian agreeing a husband is justified in hitting his wife')

# %%
dn['year'] = pd.DatetimeIndex(dn['Survey Year']).year
dn['year']
dn
# Out:
# C:\Users\mk634\AppData\Local\Temp\ipykernel_1968\2775976087.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dn['year'] = pd.DatetimeIndex(dn['Survey Year']).year
#        RecordID      Country Gender Demographics Question  \
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 4             1  Afghanistan      F        Marital status
# 5             1  Afghanistan      F            Employment
# ...         ...          ...    ...                   ...
# 12595       210     Zimbabwe      M             Residence
# 12596       280     Zimbabwe      M             Residence
# 12597       280     Zimbabwe      M             Residence
# 12598       350     Zimbabwe      M             Residence
# 12599       350     Zimbabwe      M             Residence
#
#               Demographics Response                                 Question  \
# 1                            Higher                ... if she burns the food
# 2                         Secondary                ... if she burns the food
# 3                           Primary                ... if she burns the food
# 4      Widowed, divorced, separated                ... if she burns the food
# 5                 Employed for kind                ... if she burns the food
# ...                             ...                                      ...
# 12595                         Urban  ... if she goes out without telling him
# 12596                         Rural         ... if she neglects the children
# 12597                         Urban         ... if she neglects the children
# 12598                         Rural  ... if she refuses to have sex with him
# 12599                         Urban  ... if she refuses to have sex with him
#
#       Survey Year  Value  year
# 1      01/01/2015   10.1  2015
# 2      01/01/2015   13.7  2015
# 3      01/01/2015   13.8  2015
# 4      01/01/2015   13.8  2015
# 5      01/01/2015   17.0  2015
# ...           ...    ...   ...
# 12595  01/01/2015   11.8  2015
# 12596  01/01/2015   20.1  2015
# 12597  01/01/2015   15.0  2015
# 12598  01/01/2015    7.2  2015
# 12599  01/01/2015    3.7  2015
#
# [11187 rows x 9 columns]

# %%
sns.lineplot(data=dn, x="year", y="Value",hue="Gender")
plt.xticks(rotation=10);

# %%
@interact
def summary(vis= list(dn['Question'].value_counts().index)):
    x=dn[dn['Question']==vis]
    print("-------------------------------")
    print("Statistics for Violence")
    print("Minimum violence occured: ",x['Value'].min() )
    print("Average violence occured:",x['Value'].mean())
    print("Maximum violence occured:",x['Value'].max())
# Out:
# interactive(children=(Dropdown(description='vis', options=('... for at least one specific reason', '... if she…

# %%
@interact
def summary(vis= list(dn['Demographics Question'].value_counts().index)):
    x=dn[dn['Demographics Question']==vis]
    print("-------------------------------")
    print("Statistics for Violence")
    print("Minimum violence occured: ",x['Value'].min() )
    print("Average violence occured:",x['Value'].mean())
    print("Maximum violence occured:",x['Value'].max())
# Out:
# interactive(children=(Dropdown(description='vis', options=('Education', 'Age', 'Employment', 'Marital status',…

# %%
@interact
def summary(vis= list(dn['Gender'].value_counts().index)):
    x=dn[dn['Gender']==vis]
    print("-------------------------------")
    print("Minimum violence occured: ",x['Value'].min() )
    print("Average violence occured:",x['Value'].mean())
    print("Maximum violence occured:",x['Value'].max())
# Out:
# interactive(children=(Dropdown(description='vis', options=('F', 'M'), value='F'), Output()), _dom_classes=('wi…

# %%
demographics_df = dn.groupby(["Demographics Question", "Demographics Response"])["Value"].agg(["median", "max", "min", "mean"]).reset_index()
demographics_df
# Out:
#    Demographics Question         Demographics Response  median   max  min  \
# 0                    Age                         15-24   17.50  80.1  0.1
# 1                    Age                         25-34   14.45  81.5  0.1
# 2                    Age                         35-49   14.15  81.0  0.2
# 3              Education                        Higher    4.20  74.6  0.0
# 4              Education                  No education   21.55  82.0  0.0
# 5              Education                       Primary   18.40  80.5  0.1
# 6              Education                     Secondary   13.05  76.7  0.2
# 7             Employment             Employed for cash   14.85  81.5  0.1
# 8             Employment             Employed for kind   20.15  86.9  0.3
# 9             Employment                    Unemployed   14.55  80.1  0.0
# 10        Marital status    Married or living together   14.80  82.1  0.2
# 11        Marital status                 Never married   14.90  72.1  0.0
# 12        Marital status  Widowed, divorced, separated   17.15  75.9  0.0
# 13             Residence                         Rural   19.00  82.1  0.2
# 14             Residence                         Urban   11.05  74.4  0.1
#
#          mean
# 0   21.084169
# 1   19.703562
# 2   19.336412
# 3    8.898670
# 4   25.403125
# 5   22.819093
# 6   17.378892
# 7   19.553804
# 8   24.445541
# 9   19.539710
# 10  20.181003
# 11  18.704360
# 12  20.683511
# 13  23.294063
# 14  15.895778

# %%
question_dn=dn.groupby(["Question"])["Value"].agg(["median","max","min","mean"]).reset_index()
question_dn
# Out:
#                                   Question  median   max  min       mean
# 0     ... for at least one specific reason    31.0  86.9  0.0  33.217152
# 1               ... if she argues with him    15.7  76.5  0.0  18.983652
# 2                ... if she burns the food     6.4  56.7  0.0   9.203445
# 3  ... if she goes out without telling him    16.4  77.0  0.0  20.046321
# 4         ... if she neglects the children    20.8  75.6  0.0  23.461249
# 5  ... if she refuses to have sex with him     9.0  68.7  0.0  13.209613

# %%
dn['year']=pd.DatetimeIndex(dn["Survey Year"]).year
survey_dn=dn.groupby(["year"])["Value"].agg(["median","max","min","mean"]).reset_index()
survey_dn
# Out:
# C:\Users\mk634\AppData\Local\Temp\ipykernel_1968\159612108.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dn['year']=pd.DatetimeIndex(dn["Survey Year"]).year
#     year  median   max  min       mean
# 0   2000   36.30  72.6  6.6  36.190000
# 1   2001    5.40  22.6  0.0   6.618889
# 2   2002   48.70  82.8  5.1  46.186667
# 3   2003   48.90  86.1  1.1  45.213333
# 4   2005    7.75  43.6  0.6  11.009259
# 5   2006   16.70  74.3  0.2  22.138218
# 6   2007    2.35  22.0  0.1   3.692308
# 7   2008    9.45  36.9  0.4  12.419595
# 8   2009    6.80  34.0  0.0   8.945556
# 9   2010   19.65  47.6  0.0  20.393333
# 10  2011   18.20  68.9  0.3  21.032424
# 11  2012   15.25  63.2  0.0  19.089271
# 12  2013   17.20  77.1  0.0  20.750507
# 13  2014   15.25  79.6  0.0  19.071359
# 14  2015   11.70  86.9  0.0  17.548029
# 15  2016   14.90  85.2  0.0  20.617394
# 16  2017   13.20  70.1  0.0  17.611535
# 17  2018   41.50  83.3  2.6  39.838056

# %%
country_dn=dn.groupby(["Country"])["Value"].agg(["median","max","min","mean"]).reset_index()
country_dn.sort_values(['Country','max'])
# Out:
#         Country  median   max  min       mean
# 0   Afghanistan   44.50  86.9  4.5  42.683333
# 1       Albania    3.75  29.7  0.0   5.417778
# 2        Angola   11.80  37.4  0.6  13.202222
# 3       Armenia    6.95  47.0  0.0   9.553571
# 4    Azerbaijan   33.95  74.3  1.5  32.666071
# ..          ...     ...   ...  ...        ...
# 65       Uganda   23.60  59.8  1.5  24.840556
# 66      Ukraine    2.35  22.0  0.1   3.692308
# 67        Yemen   28.20  61.6  1.3  27.621111
# 68       Zambia   23.90  63.7  0.7  24.361667
# 69     Zimbabwe   16.60  55.2  1.1  18.170556
#
# [70 rows x 5 columns]

# %%
response_dn=dn.groupby(["Gender"])["Value"].agg(["median","max","min","mean"]).reset_index()
response_dn
# Out:
#   Gender  median   max  min       mean
# 0      F    18.3  86.9  0.0  22.936350
# 1      M    12.0  77.4  0.0  15.897205

# %%
demoresponse_dn=dn.groupby(["Demographics Response"])["Value"].agg(["median","max","min","mean"]).reset_index()
demoresponse_dn
# Out:
#            Demographics Response  median   max  min       mean
# 0                          15-24   17.50  80.1  0.1  21.084169
# 1                          25-34   14.45  81.5  0.1  19.703562
# 2                          35-49   14.15  81.0  0.2  19.336412
# 3              Employed for cash   14.85  81.5  0.1  19.553804
# 4              Employed for kind   20.15  86.9  0.3  24.445541
# 5                         Higher    4.20  74.6  0.0   8.898670
# 6     Married or living together   14.80  82.1  0.2  20.181003
# 7                  Never married   14.90  72.1  0.0  18.704360
# 8                   No education   21.55  82.0  0.0  25.403125
# 9                        Primary   18.40  80.5  0.1  22.819093
# 10                         Rural   19.00  82.1  0.2  23.294063
# 11                     Secondary   13.05  76.7  0.2  17.378892
# 12                    Unemployed   14.55  80.1  0.0  19.539710
# 13                         Urban   11.05  74.4  0.1  15.895778
# 14  Widowed, divorced, separated   17.15  75.9  0.0  20.683511

# %%
female=India[India.Gender == 'F']
female
# Out:
#       RecordID Country Gender Demographics Question Demographics Response  \
# 5580        32   India      F             Education                Higher
# 5581        32   India      F             Residence                 Urban
# 5582        32   India      F        Marital status         Never married
# 5583        32   India      F             Education             Secondary
# 5584        32   India      F                   Age                 15-24
# ...        ...     ...    ...                   ...                   ...
# 5680       172   India      F             Residence                 Urban
# 5681       242   India      F             Residence                 Rural
# 5682       242   India      F             Residence                 Urban
# 5683       312   India      F             Residence                 Rural
# 5684       312   India      F             Residence                 Urban
#
#                                      Question Survey Year  Value
# 5580                ... if she burns the food  01/01/2015   11.4
# 5581                ... if she burns the food  01/01/2015   15.2
# 5582                ... if she burns the food  01/01/2015   15.8
# 5583                ... if she burns the food  01/01/2015   17.3
# 5584                ... if she burns the food  01/01/2015   17.5
# ...                                       ...         ...    ...
# 5680  ... if she goes out without telling him  01/01/2015   23.3
# 5681         ... if she neglects the children  01/01/2015   34.5
# 5682         ... if she neglects the children  01/01/2015   29.7
# 5683  ... if she refuses to have sex with him  01/01/2015   14.6
# 5684  ... if she refuses to have sex with him  01/01/2015   11.0
#
# [90 rows x 8 columns]

# %%
arguing=female[female.Question == '... if she argues with him']
arguing
# Out:
#       RecordID Country Gender Demographics Question  \
# 5613       102   India      F                   Age
# 5614       102   India      F                   Age
# 5615       102   India      F                   Age
# 5629       102   India      F             Education
# 5630       102   India      F             Education
# 5631       102   India      F             Education
# 5632       102   India      F             Education
# 5648       102   India      F            Employment
# 5649       102   India      F            Employment
# 5650       102   India      F            Employment
# 5663       102   India      F        Marital status
# 5664       102   India      F        Marital status
# 5665       102   India      F        Marital status
# 5677       102   India      F             Residence
# 5678       102   India      F             Residence
#
#              Demographics Response                    Question Survey Year  \
# 5613                         15-24  ... if she argues with him  01/01/2015
# 5614                         25-34  ... if she argues with him  01/01/2015
# 5615                         35-49  ... if she argues with him  01/01/2015
# 5629                        Higher  ... if she argues with him  01/01/2015
# 5630                  No education  ... if she argues with him  01/01/2015
# 5631                       Primary  ... if she argues with him  01/01/2015
# 5632                     Secondary  ... if she argues with him  01/01/2015
# 5648             Employed for cash  ... if she argues with him  01/01/2015
# 5649             Employed for kind  ... if she argues with him  01/01/2015
# 5650                    Unemployed  ... if she argues with him  01/01/2015
# 5663    Married or living together  ... if she argues with him  01/01/2015
# 5664                 Never married  ... if she argues with him  01/01/2015
# 5665  Widowed, divorced, separated  ... if she argues with him  01/01/2015
# 5677                         Rural  ... if she argues with him  01/01/2015
# 5678                         Urban  ... if she argues with him  01/01/2015
#
#       Value
# 5613   26.4
# 5614   29.1
# 5615   31.7
# 5629   18.4
# 5630   36.2
# 5631   33.1
# 5632   27.2
# 5648   33.6
# 5649   36.6
# 5650   26.9
# 5663   30.7
# 5664   23.6
# 5665   31.3
# 5677   32.0
# 5678   24.0

# %%
dataframe_arg = arguing.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_arg
# Out:
#            Demographics Response  mean
# 0                          15-24  26.4
# 1                          25-34  29.1
# 2                          35-49  31.7
# 3              Employed for cash  33.6
# 4              Employed for kind  36.6
# 5                         Higher  18.4
# 6     Married or living together  30.7
# 7                  Never married  23.6
# 8                   No education  36.2
# 9                        Primary  33.1
# 10                         Rural  32.0
# 11                     Secondary  27.2
# 12                    Unemployed  26.9
# 13                         Urban  24.0
# 14  Widowed, divorced, separated  31.3

# %%
burn=female[female.Question == '... if she burns the food']
burn
# Out:
#       RecordID Country Gender Demographics Question  \
# 5580        32   India      F             Education
# 5581        32   India      F             Residence
# 5582        32   India      F        Marital status
# 5583        32   India      F             Education
# 5584        32   India      F                   Age
# 5585        32   India      F            Employment
# 5586        32   India      F                   Age
# 5587        32   India      F        Marital status
# 5588        32   India      F                   Age
# 5589        32   India      F             Education
# 5590        32   India      F            Employment
# 5591        32   India      F             Residence
# 5592        32   India      F        Marital status
# 5593        32   India      F             Education
# 5594        32   India      F            Employment
#
#              Demographics Response                   Question Survey Year  \
# 5580                        Higher  ... if she burns the food  01/01/2015
# 5581                         Urban  ... if she burns the food  01/01/2015
# 5582                 Never married  ... if she burns the food  01/01/2015
# 5583                     Secondary  ... if she burns the food  01/01/2015
# 5584                         15-24  ... if she burns the food  01/01/2015
# 5585                    Unemployed  ... if she burns the food  01/01/2015
# 5586                         25-34  ... if she burns the food  01/01/2015
# 5587    Married or living together  ... if she burns the food  01/01/2015
# 5588                         35-49  ... if she burns the food  01/01/2015
# 5589                       Primary  ... if she burns the food  01/01/2015
# 5590             Employed for cash  ... if she burns the food  01/01/2015
# 5591                         Rural  ... if she burns the food  01/01/2015
# 5592  Widowed, divorced, separated  ... if she burns the food  01/01/2015
# 5593                  No education  ... if she burns the food  01/01/2015
# 5594             Employed for kind  ... if she burns the food  01/01/2015
#
#       Value
# 5580   11.4
# 5581   15.2
# 5582   15.8
# 5583   17.3
# 5584   17.5
# 5585   17.8
# 5586   18.8
# 5587   20.0
# 5588   21.1
# 5589   21.1
# 5590   21.4
# 5591   21.4
# 5592   22.4
# 5593   25.6
# 5594   25.8

# %%
dataframe_burn = burn.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_burn
# Out:
#            Demographics Response  mean
# 0                          15-24  17.5
# 1                          25-34  18.8
# 2                          35-49  21.1
# 3              Employed for cash  21.4
# 4              Employed for kind  25.8
# 5                         Higher  11.4
# 6     Married or living together  20.0
# 7                  Never married  15.8
# 8                   No education  25.6
# 9                        Primary  21.1
# 10                         Rural  21.4
# 11                     Secondary  17.3
# 12                    Unemployed  17.8
# 13                         Urban  15.2
# 14  Widowed, divorced, separated  22.4

# %%
neglect=female[female.Question == '... if she neglects the children']
neglect
# Out:
#       RecordID Country Gender Demographics Question  \
# 5619       242   India      F                   Age
# 5620       242   India      F                   Age
# 5621       242   India      F                   Age
# 5637       242   India      F             Education
# 5638       242   India      F             Education
# 5639       242   India      F             Education
# 5640       242   India      F             Education
# 5654       242   India      F            Employment
# 5655       242   India      F            Employment
# 5656       242   India      F            Employment
# 5669       242   India      F        Marital status
# 5670       242   India      F        Marital status
# 5671       242   India      F        Marital status
# 5681       242   India      F             Residence
# 5682       242   India      F             Residence
#
#              Demographics Response                          Question  \
# 5619                         15-24  ... if she neglects the children
# 5620                         25-34  ... if she neglects the children
# 5621                         35-49  ... if she neglects the children
# 5637                        Higher  ... if she neglects the children
# 5638                  No education  ... if she neglects the children
# 5639                       Primary  ... if she neglects the children
# 5640                     Secondary  ... if she neglects the children
# 5654             Employed for cash  ... if she neglects the children
# 5655             Employed for kind  ... if she neglects the children
# 5656                    Unemployed  ... if she neglects the children
# 5669    Married or living together  ... if she neglects the children
# 5670                 Never married  ... if she neglects the children
# 5671  Widowed, divorced, separated  ... if she neglects the children
# 5681                         Rural  ... if she neglects the children
# 5682                         Urban  ... if she neglects the children
#
#      Survey Year  Value
# 5619  01/01/2015   30.4
# 5620  01/01/2015   32.8
# 5621  01/01/2015   35.1
# 5637  01/01/2015   25.2
# 5638  01/01/2015   37.2
# 5639  01/01/2015   35.1
# 5640  01/01/2015   31.9
# 5654  01/01/2015   38.7
# 5655  01/01/2015   37.3
# 5656  01/01/2015   30.3
# 5669  01/01/2015   34.0
# 5670  01/01/2015   28.1
# 5671  01/01/2015   36.9
# 5681  01/01/2015   34.5
# 5682  01/01/2015   29.7

# %%
dataframe_neglect = neglect.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_neglect
# Out:
#            Demographics Response  mean
# 0                          15-24  30.4
# 1                          25-34  32.8
# 2                          35-49  35.1
# 3              Employed for cash  38.7
# 4              Employed for kind  37.3
# 5                         Higher  25.2
# 6     Married or living together  34.0
# 7                  Never married  28.1
# 8                   No education  37.2
# 9                        Primary  35.1
# 10                         Rural  34.5
# 11                     Secondary  31.9
# 12                    Unemployed  30.3
# 13                         Urban  29.7
# 14  Widowed, divorced, separated  36.9

# %%
goesout=female[female.Question == '... if she goes out without telling him']
goesout
# Out:
#       RecordID Country Gender Demographics Question  \
# 5616       172   India      F                   Age
# 5617       172   India      F                   Age
# 5618       172   India      F                   Age
# 5633       172   India      F             Education
# 5634       172   India      F             Education
# 5635       172   India      F             Education
# 5636       172   India      F             Education
# 5651       172   India      F            Employment
# 5652       172   India      F            Employment
# 5653       172   India      F            Employment
# 5666       172   India      F        Marital status
# 5667       172   India      F        Marital status
# 5668       172   India      F        Marital status
# 5679       172   India      F             Residence
# 5680       172   India      F             Residence
#
#              Demographics Response                                 Question  \
# 5616                         15-24  ... if she goes out without telling him
# 5617                         25-34  ... if she goes out without telling him
# 5618                         35-49  ... if she goes out without telling him
# 5633                        Higher  ... if she goes out without telling him
# 5634                  No education  ... if she goes out without telling him
# 5635                       Primary  ... if she goes out without telling him
# 5636                     Secondary  ... if she goes out without telling him
# 5651             Employed for cash  ... if she goes out without telling him
# 5652             Employed for kind  ... if she goes out without telling him
# 5653                    Unemployed  ... if she goes out without telling him
# 5666    Married or living together  ... if she goes out without telling him
# 5667                 Never married  ... if she goes out without telling him
# 5668  Widowed, divorced, separated  ... if she goes out without telling him
# 5679                         Rural  ... if she goes out without telling him
# 5680                         Urban  ... if she goes out without telling him
#
#      Survey Year  Value
# 5616  01/01/2015   23.6
# 5617  01/01/2015   26.2
# 5618  01/01/2015   28.6
# 5633  01/01/2015   18.4
# 5634  01/01/2015   31.7
# 5635  01/01/2015   28.9
# 5636  01/01/2015   24.6
# 5651  01/01/2015   30.6
# 5652  01/01/2015   31.9
# 5653  01/01/2015   24.1
# 5666  01/01/2015   27.5
# 5667  01/01/2015   21.3
# 5668  01/01/2015   29.5
# 5679  01/01/2015   27.7
# 5680  01/01/2015   23.3

# %%
dataframe_goesout = goesout.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_goesout
# Out:
#            Demographics Response  mean
# 0                          15-24  23.6
# 1                          25-34  26.2
# 2                          35-49  28.6
# 3              Employed for cash  30.6
# 4              Employed for kind  31.9
# 5                         Higher  18.4
# 6     Married or living together  27.5
# 7                  Never married  21.3
# 8                   No education  31.7
# 9                        Primary  28.9
# 10                         Rural  27.7
# 11                     Secondary  24.6
# 12                    Unemployed  24.1
# 13                         Urban  23.3
# 14  Widowed, divorced, separated  29.5

# %%
refuses=female[female.Question == '... if she refuses to have sex with him']
refuses
# Out:
#       RecordID Country Gender Demographics Question  \
# 5622       312   India      F                   Age
# 5623       312   India      F                   Age
# 5624       312   India      F                   Age
# 5641       312   India      F             Education
# 5642       312   India      F             Education
# 5643       312   India      F             Education
# 5644       312   India      F             Education
# 5657       312   India      F            Employment
# 5658       312   India      F            Employment
# 5659       312   India      F            Employment
# 5672       312   India      F        Marital status
# 5673       312   India      F        Marital status
# 5674       312   India      F        Marital status
# 5683       312   India      F             Residence
# 5684       312   India      F             Residence
#
#              Demographics Response                                 Question  \
# 5622                         15-24  ... if she refuses to have sex with him
# 5623                         25-34  ... if she refuses to have sex with him
# 5624                         35-49  ... if she refuses to have sex with him
# 5641                        Higher  ... if she refuses to have sex with him
# 5642                  No education  ... if she refuses to have sex with him
# 5643                       Primary  ... if she refuses to have sex with him
# 5644                     Secondary  ... if she refuses to have sex with him
# 5657             Employed for cash  ... if she refuses to have sex with him
# 5658             Employed for kind  ... if she refuses to have sex with him
# 5659                    Unemployed  ... if she refuses to have sex with him
# 5672    Married or living together  ... if she refuses to have sex with him
# 5673                 Never married  ... if she refuses to have sex with him
# 5674  Widowed, divorced, separated  ... if she refuses to have sex with him
# 5683                         Rural  ... if she refuses to have sex with him
# 5684                         Urban  ... if she refuses to have sex with him
#
#      Survey Year  Value
# 5622  01/01/2015   11.4
# 5623  01/01/2015   13.4
# 5624  01/01/2015   15.1
# 5641  01/01/2015    8.1
# 5642  01/01/2015   17.6
# 5643  01/01/2015   15.3
# 5644  01/01/2015   11.9
# 5657  01/01/2015   15.2
# 5658  01/01/2015   17.8
# 5659  01/01/2015   12.3
# 5672  01/01/2015   14.3
# 5673  01/01/2015    9.7
# 5674  01/01/2015   16.3
# 5683  01/01/2015   14.6
# 5684  01/01/2015   11.0

# %%
dataframe_refuses = refuses.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_refuses
# Out:
#            Demographics Response  mean
# 0                          15-24  11.4
# 1                          25-34  13.4
# 2                          35-49  15.1
# 3              Employed for cash  15.2
# 4              Employed for kind  17.8
# 5                         Higher   8.1
# 6     Married or living together  14.3
# 7                  Never married   9.7
# 8                   No education  17.6
# 9                        Primary  15.3
# 10                         Rural  14.6
# 11                     Secondary  11.9
# 12                    Unemployed  12.3
# 13                         Urban  11.0
# 14  Widowed, divorced, separated  16.3

# %%
specific=female[female.Question == '... for at least one specific reason']
specific
# Out:
#       RecordID Country Gender Demographics Question  \
# 5610       382   India      F                   Age
# 5611       382   India      F                   Age
# 5612       382   India      F                   Age
# 5625       382   India      F             Education
# 5626       382   India      F             Education
# 5627       382   India      F             Education
# 5628       382   India      F             Education
# 5645       382   India      F            Employment
# 5646       382   India      F            Employment
# 5647       382   India      F            Employment
# 5660       382   India      F        Marital status
# 5661       382   India      F        Marital status
# 5662       382   India      F        Marital status
# 5675       382   India      F             Residence
# 5676       382   India      F             Residence
#
#              Demographics Response                              Question  \
# 5610                         15-24  ... for at least one specific reason
# 5611                         25-34  ... for at least one specific reason
# 5612                         35-49  ... for at least one specific reason
# 5625                        Higher  ... for at least one specific reason
# 5626                  No education  ... for at least one specific reason
# 5627                       Primary  ... for at least one specific reason
# 5628                     Secondary  ... for at least one specific reason
# 5645             Employed for cash  ... for at least one specific reason
# 5646             Employed for kind  ... for at least one specific reason
# 5647                    Unemployed  ... for at least one specific reason
# 5660    Married or living together  ... for at least one specific reason
# 5661                 Never married  ... for at least one specific reason
# 5662  Widowed, divorced, separated  ... for at least one specific reason
# 5675                         Rural  ... for at least one specific reason
# 5676                         Urban  ... for at least one specific reason
#
#      Survey Year  Value
# 5610  01/01/2015   41.6
# 5611  01/01/2015   44.7
# 5612  01/01/2015   47.7
# 5625  01/01/2015   33.8
# 5626  01/01/2015   51.6
# 5627  01/01/2015   48.4
# 5628  01/01/2015   42.9
# 5645  01/01/2015   50.9
# 5646  01/01/2015   52.4
# 5647  01/01/2015   41.8
# 5660  01/01/2015   46.5
# 5661  01/01/2015   38.4
# 5662  01/01/2015   47.4
# 5675  01/01/2015   47.4
# 5676  01/01/2015   39.8

# %%
dataframe_specific = specific.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_specific
# Out:
#            Demographics Response  mean
# 0                          15-24  41.6
# 1                          25-34  44.7
# 2                          35-49  47.7
# 3              Employed for cash  50.9
# 4              Employed for kind  52.4
# 5                         Higher  33.8
# 6     Married or living together  46.5
# 7                  Never married  38.4
# 8                   No education  51.6
# 9                        Primary  48.4
# 10                         Rural  47.4
# 11                     Secondary  42.9
# 12                    Unemployed  41.8
# 13                         Urban  39.8
# 14  Widowed, divorced, separated  47.4

# %%
male=India[India.Gender == 'M']
male
# Out:
#       RecordID Country Gender Demographics Question  \
# 5595        32   India      M             Education
# 5596        32   India      M             Residence
# 5597        32   India      M                   Age
# 5598        32   India      M        Marital status
# 5599        32   India      M             Education
# ...        ...     ...    ...                   ...
# 5755       172   India      M             Residence
# 5756       242   India      M             Residence
# 5757       242   India      M             Residence
# 5758       312   India      M             Residence
# 5759       312   India      M             Residence
#
#            Demographics Response                                 Question  \
# 5595                      Higher                ... if she burns the food
# 5596                       Urban                ... if she burns the food
# 5597                       35-49                ... if she burns the food
# 5598  Married or living together                ... if she burns the food
# 5599                   Secondary                ... if she burns the food
# ...                          ...                                      ...
# 5755                       Urban  ... if she goes out without telling him
# 5756                       Rural         ... if she neglects the children
# 5757                       Urban         ... if she neglects the children
# 5758                       Rural  ... if she refuses to have sex with him
# 5759                       Urban  ... if she refuses to have sex with him
#
#      Survey Year  Value
# 5595  01/01/2015    7.4
# 5596  01/01/2015    8.7
# 5597  01/01/2015    9.2
# 5598  01/01/2015    9.7
# 5599  01/01/2015    9.9
# ...          ...    ...
# 5755  01/01/2015   13.9
# 5756  01/01/2015   21.0
# 5757  01/01/2015   18.0
# 5758  01/01/2015    9.8
# 5759  01/01/2015    7.8
#
# [90 rows x 8 columns]

# %%
arguing1=male[male.Question == '... if she argues with him']
arguing1
# Out:
#       RecordID Country Gender Demographics Question  \
# 5688       102   India      M                   Age
# 5689       102   India      M                   Age
# 5690       102   India      M                   Age
# 5704       102   India      M             Education
# 5705       102   India      M             Education
# 5706       102   India      M             Education
# 5707       102   India      M             Education
# 5723       102   India      M            Employment
# 5724       102   India      M            Employment
# 5725       102   India      M            Employment
# 5738       102   India      M        Marital status
# 5739       102   India      M        Marital status
# 5740       102   India      M        Marital status
# 5752       102   India      M             Residence
# 5753       102   India      M             Residence
#
#              Demographics Response                    Question Survey Year  \
# 5688                         15-24  ... if she argues with him  01/01/2015
# 5689                         25-34  ... if she argues with him  01/01/2015
# 5690                         35-49  ... if she argues with him  01/01/2015
# 5704                        Higher  ... if she argues with him  01/01/2015
# 5705                  No education  ... if she argues with him  01/01/2015
# 5706                       Primary  ... if she argues with him  01/01/2015
# 5707                     Secondary  ... if she argues with him  01/01/2015
# 5723             Employed for cash  ... if she argues with him  01/01/2015
# 5724             Employed for kind  ... if she argues with him  01/01/2015
# 5725                    Unemployed  ... if she argues with him  01/01/2015
# 5738    Married or living together  ... if she argues with him  01/01/2015
# 5739                 Never married  ... if she argues with him  01/01/2015
# 5740  Widowed, divorced, separated  ... if she argues with him  01/01/2015
# 5752                         Rural  ... if she argues with him  01/01/2015
# 5753                         Urban  ... if she argues with him  01/01/2015
#
#       Value
# 5688   22.4
# 5689   19.6
# 5690   19.3
# 5704   14.8
# 5705   27.3
# 5706   23.8
# 5707   20.1
# 5723   20.2
# 5724   25.9
# 5725   19.3
# 5738   19.5
# 5739   21.6
# 5740   26.9
# 5752   22.2
# 5753   17.6

# %%
dataframe_arg1 = arguing1.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_arg1
# Out:
#            Demographics Response  mean
# 0                          15-24  22.4
# 1                          25-34  19.6
# 2                          35-49  19.3
# 3              Employed for cash  20.2
# 4              Employed for kind  25.9
# 5                         Higher  14.8
# 6     Married or living together  19.5
# 7                  Never married  21.6
# 8                   No education  27.3
# 9                        Primary  23.8
# 10                         Rural  22.2
# 11                     Secondary  20.1
# 12                    Unemployed  19.3
# 13                         Urban  17.6
# 14  Widowed, divorced, separated  26.9

# %%
burn1=male[male.Question == '... if she burns the food']
dataframe_burn1 = burn1.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_burn1
# Out:
#            Demographics Response  mean
# 0                          15-24  11.2
# 1                          25-34  10.2
# 2                          35-49   9.2
# 3              Employed for cash   9.9
# 4              Employed for kind  14.1
# 5                         Higher   7.4
# 6     Married or living together   9.7
# 7                  Never married  11.0
# 8                   No education  14.1
# 9                        Primary  11.7
# 10                         Rural  11.1
# 11                     Secondary   9.9
# 12                    Unemployed   9.9
# 13                         Urban   8.7
# 14  Widowed, divorced, separated  11.4

# %%
neglect1=male[male.Question == '... if she neglects the children']
dataframe_neglect1 = neglect1.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_neglect1
# Out:
#            Demographics Response  mean
# 0                          15-24  20.7
# 1                          25-34  19.9
# 2                          35-49  18.9
# 3              Employed for cash  19.8
# 4              Employed for kind  24.0
# 5                         Higher  16.0
# 6     Married or living together  19.3
# 7                  Never married  20.7
# 8                   No education  24.9
# 9                        Primary  22.4
# 10                         Rural  21.0
# 11                     Secondary  19.5
# 12                    Unemployed  18.2
# 13                         Urban  18.0
# 14  Widowed, divorced, separated  22.2

# %%
goesout1=male[male.Question == '... if she goes out without telling him']
dataframe_goesout1 = goesout1.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_goesout1
# Out:
#            Demographics Response  mean
# 0                          15-24  17.5
# 1                          25-34  15.5
# 2                          35-49  14.9
# 3              Employed for cash  15.7
# 4              Employed for kind  20.2
# 5                         Higher  12.2
# 6     Married or living together  15.1
# 7                  Never married  17.2
# 8                   No education  21.7
# 9                        Primary  18.5
# 10                         Rural  17.2
# 11                     Secondary  15.4
# 12                    Unemployed  15.4
# 13                         Urban  13.9
# 14  Widowed, divorced, separated  20.0

# %%
refuses1=male[male.Question == '... if she refuses to have sex with him']
dataframe_refuses1 = refuses1.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()

# %%
dataframe_refuses1
# Out:
#            Demographics Response  mean
# 0                          15-24  10.3
# 1                          25-34   8.6
# 2                          35-49   8.1
# 3              Employed for cash   8.8
# 4              Employed for kind  10.9
# 5                         Higher   6.6
# 6     Married or living together   8.2
# 7                  Never married  10.3
# 8                   No education  13.1
# 9                        Primary  10.9
# 10                         Rural   9.8
# 11                     Secondary   8.6
# 12                    Unemployed   8.9
# 13                         Urban   7.8
# 14  Widowed, divorced, separated  11.9

# %%
specific1=male[male.Question == '... for at least one specific reason']
dataframe_specific1 = specific1.groupby(["Demographics Response"])["Value"].agg(["mean"]).reset_index()
dataframe_specific1
# Out:
#            Demographics Response  mean
# 0                          15-24  33.7
# 1                          25-34  31.3
# 2                          35-49  30.6
# 3              Employed for cash  31.7
# 4              Employed for kind  39.1
# 5                         Higher  25.4
# 6     Married or living together  30.8
# 7                  Never married  33.5
# 8                   No education  39.3
# 9                        Primary  35.8
# 10                         Rural  34.1
# 11                     Secondary  31.6
# 12                    Unemployed  29.8
# 13                         Urban  28.4
# 14  Widowed, divorced, separated  36.3

# %% [markdown]
# # Data Analysis

# %% [markdown]
# a) 2018 was the year that recorded with the most agreed key questions that were asked
#
# b) The country which had the highest % average of people who agreed with the key question was Eritrea with an average of 46.19%
#
# c) The most agreeable question was that the husband is justified in beating his wife for at least one specific reason with the highest % average being in 2018 for females at 70.39% and males at 48.84%
#
# d) We can also see that females have the highest % of responses compared to males across all key question this could be due to some socioeconomic factors affecting the communities across the world
#
# e) In the demographic age we can also see that ages 15-24 has the highest % average of agreement with the key question husband is justified in beating his wife for at least one specific reason coming to 35.88% which is the highest across other age groups
#
# f) In the demographic Education group we can see that for females those who have received no education agree to the key question that a husband is justified to beating his wife for at least one specific reason with a percentage of 45.45% compares to males in the same education category where there average % was 32.81%
#
# g) In the demographic group of residence we see that those who live in rural areas have a highest % responses of the key question that husband is justified in beating his wife for at least one specific reason coming to 42.24% for both genders and the ones in urban at 30.94%

# %% [markdown]
# # CONCLUSIONS FROM THE ANALYSIS

# %% [markdown]
# b The key question that a husband is justified in hitting his wife for any reason has the highest % of agreed responses from both male and female, we can conclude this could be because of the social construct that a man is the head of the house so they do not need to explain themsleves when it comes to abuse or violence in their homes, the way forward is to start teaching equality in homes that a wife is as important in the household as a husband, changing the view of what is commonly known as household heirarchy
